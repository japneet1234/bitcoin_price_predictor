# %% [markdown]
# # Installs

# %%
# %pip install tensorflow
# %pip install keras
# %pip install tqdm
# %pip install lightgbm

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm
from datetime import datetime
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression as LR
from sklearn.neighbors import KNeighborsRegressor as KNR
from sklearn.neural_network import MLPRegressor as MLP
from sklearn.svm import LinearSVR as SVR
from sklearn.ensemble import RandomForestRegressor as RFR
from lightgbm import LGBMRegressor as LGB
from sklearn.multioutput import RegressorChain as RC

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM
from keras import backend as K

from sklearn.preprocessing import MinMaxScaler as MM
from sklearn.preprocessing import StandardScaler as SS

from sklearn.model_selection import train_test_split as tts

from sklearn.metrics import r2_score as r2_s
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv("bitcoin_price_Training - Training.csv",thousands=',')

# %%
df.head(2)
# Out:
#            Date     Open     High      Low    Close       Volume   Market Cap
# 0  Jul 31, 2017  2763.24  2889.62  2720.61  2875.34  860,575,000  45535800000
# 1  Jul 30, 2017  2724.39  2758.53  2644.85  2757.18  705,943,000  44890700000

# %%
df.shape
# Out:
# (1556, 7)

# %% [markdown]
# # Preprocessing and Visualization

# %%
df.dtypes
# Out:
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap      int64
# dtype: object

# %%
# setting the date column as index

df.index = pd.to_datetime(df['Date'].apply(lambda x: datetime.strptime(x, "%b %d, %Y")))
df.drop(['Date'],axis=1,inplace=True)

# %%
# Sorted the dataframe in order of increasing dates so as to split the data into train and test where last part of the df would serve as test (future prediction)

df = df.sort_index()

# %%
# Volume column has nan values disguised as "-", hence replacing them with nan
# And for converting datatype of volume column to int, replacing the commas with space and then did datatype conversion

df = df.replace({"-":np.nan})
df['Volume'] = df['Volume'].str.replace(',', '').astype(float)

# %%
# Checking the number of null values

df.isnull().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume        243
# Market Cap      0
# dtype: int64

# %%
# Checking the length of dataframe to get an idea of what should be done with null values

df.shape
# Out:
# (1556, 6)

# %%
# Since 15% values are null, so dropping the rows would result in loss of information
# Hence, interpolating the null values using 'forward' method

df = df.interpolate(method ='linear', limit_direction ='forward')
df.isnull().sum().sum()
# Out:
# np.int64(243)

# %%
# Created a column Difference which depicted the difference between Hight and Low columns

df['Difference'] = df['High'] - df['Low']

# %%
df.head(2)
# Out:
#               Open    High    Low   Close  Volume  Market Cap  Difference
# Date
# 2013-04-28  135.30  135.98  132.1  134.21     NaN  1500520000        3.88
# 2013-04-29  134.44  147.49  134.0  144.54     NaN  1491160000       13.49

# %%
# Visualizing the correlation among the different columns woth help of a heatmap

sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,5))
for i in df.columns[:4]:
  plt.plot(np.arange(df.shape[0]),df[i],label=f'{i}',alpha=0.8)
plt.title("Bitcoin Prices")
plt.xticks(np.arange(0,df.shape[0],90),[df.index[i].strftime("%b'%y") for i in range(df.shape[0]) if i%90==0])
plt.legend()
plt.show()

# %%
# function that creates a dataframe consisting of only Close columns, according to the day whose Close price is to be predicted and
# number of previous days whose data is to be used for that prediction

def transform_df(df,days_to_predict,look_back,keep_cols=None,window_size=1):
    df_new = pd.DataFrame()
    for i in range(look_back):
        df_new[f'Close_t+{i}'] = df['Close'].shift(-i)
        if keep_cols!=None:
            for j in keep_cols:
                df_new[f'{j}+{i}'] = df[{j}].shift(-i)
    for i in range(window_size):
        df_new[f'Prediction_t+{i+days_to_predict}'] = df['Close'].shift(-i-days_to_predict)
    df_new.dropna(inplace=True)
    return df_new

# %%
# function that splits a datframe into train and test sets

def get_X_y_tts(df,split_ratio=0.7):
  i = 0
  for j in range(len(df.columns)):
    if df.columns[j].startswith('P'):
      i=j
      break

  X = df.iloc[:,:i]
  y = df.iloc[:,i:]
  tts = round(len(X)*split_ratio)
  X_train = X.iloc[:tts,:]
  X_test = X.iloc[tts:,:]
  y_train = y.iloc[:tts]
  y_test = y.iloc[tts:]
  return X_train,X_test,y_train,y_test

# %%
# function to normalize the data

def get_scaled(train,test):
  ss = SS()
  train = ss.fit_transform(train)
  test = ss.transform(test)
  return train,test

# %% [markdown]
# # Training and Visualizing results

# %%
# initializing a list of models which are to be trained and list of metrics for evaluation

models = [LR(),KNR(),MLP(),SVR(),RFR(),LGB()]
model_names = ["LinearRegression", "KNearestNeighbour", "MultilayerPerceptron", "SupportVectorRegression", "RandomForestRegressor", "LightGBMRegressor"]
metrics_short_names = ['mse','mae','r2']
metrics_arr = ['Mean_Absolute_Error','Mean_Squared_Error','R2_Score']
model_short_names = ['LinReg', 'KNN', 'MLP', 'SVM', 'RF', 'LGBM']

# %%
# this function trains different models and stores the model, predicted values, errors and r2score for each of them in dictionary

def get_performance(X_train,y_train,X_test,y_test):
  performance = {}
  for i in tqdm(range(len(models)),desc='models'):
    d = {}
    m = models[i]
    if(y_test.shape[1]!=1):
      m = RC(m)
    m = m.fit(X_train,y_train)
    yptr = m.predict(X_train)
    ypts = m.predict(X_test)
    d["model"] = m
    d["yptr"] = yptr
    d["ypts"] = ypts
    d["tr_scores"] = {"mse":mse(y_train,yptr),"mae":mae(y_train,yptr),"r2":r2_s(y_train,yptr)}
    d["ts_scores"] = {"mse":mse(y_test,ypts),"mae":mae(y_test,ypts),"r2":r2_s(y_test,ypts)}
    performance[f"{model_names[i]}"]=d
  return performance

# prints mean_absolute_error, mean_squared_error and r2_score

def print_metrics(performance):
  for i in performance.keys():
    print(f"{i}:")
    print(f"Train scores:{performance[i]['tr_scores']}")
    print(f"Test scores:{performance[i]['ts_scores']}")
    print()

# plots the y_train vs y_predicted and y_test vs y_predicted

def plot_pred(performance,y_train,y_test):
  train_len = len(y_train)
  test_len = len(y_test)
  for i in performance.keys():
    if(y_train.shape[1]==1):

      fig, axs = plt.subplots(1, 2,figsize=(24,4))
      axs[0].plot(np.arange(train_len),y_train,label='Actual')
      axs[0].plot(np.arange(train_len),performance[i]['yptr'],label='Predicted',alpha=0.8)
      axs[0].set_title(f"y_train")
      axs[0].legend()

      axs[1].plot(np.arange(test_len),y_test,label='Actual')
      axs[1].plot(np.arange(test_len),performance[i]['ypts'],label='Predicted',alpha=0.8)
      axs[1].set_title(f"y_test")
      axs[1].legend()
      plt.suptitle(f"{i}")
      plt.show()

    else:

      fig, axs = plt.subplots(2, y_train.shape[1],figsize=(24,8))
      for j in range(y_train.shape[1]):
          axs[0][j].plot(np.arange(train_len),y_train_scaled2[:,j],label='Actual')
          axs[0][j].plot(np.arange(train_len),performance2[i]['yptr'][:,j],label='Predicted',alpha=0.8)
          axs[0][j].set_title(f"y_train[{j}]")
          axs[0][j].legend()

          axs[1][j].plot(np.arange(test_len),y_test_scaled2[:,j],label='Actual')
          axs[1][j].plot(np.arange(test_len),performance2[i]['ypts'][:,j],label='Predicted',alpha=0.8)
          axs[1][j].set_title(f"y_test[{j}]")
          axs[1][j].legend()
      plt.suptitle(f"{i}")
      plt.show()

# comparing the erros and r2_score of different models applied

def compare_models(performance):
  fig, axs = plt.subplots(1, 3,figsize=(24,5))
  for i in range(3):
      axs[i].plot(np.arange(len(models)),[performance[j]["tr_scores"][metrics_short_names[i]] for j in performance.keys()],label='Train',marker='o')
      axs[i].plot(np.arange(len(models)),[performance[j]["ts_scores"][metrics_short_names[i]] for j in performance.keys()],label='Test',marker='o')
      axs[i].set_xticks(np.arange(len(models)))
      axs[i].set_xticklabels(model_short_names)
      axs[i].set_title(f"{metrics_arr[i]}")
      axs[i].legend()
  plt.show()

# %% [markdown]
# ## Transformation 1

# %% [markdown]
# > Creating a dataframe where Close price of 5 days is given as input and close price of 6th day is to be predicted

# %%
df1 = transform_df(df,5,5)
X_train1, X_test1, y_train1, y_test1 = get_X_y_tts(df1,0.7)
X_train_scaled1, X_test_scaled1 = get_scaled(X_train1,X_test1)
y_train_scaled1, y_test_scaled1 = get_scaled(y_train1.values.reshape(-1,1),y_test1.values.reshape(-1,1))

# %%
X_train1.head(2)
# Out:
#             Close_t+0  Close_t+1  Close_t+2  Close_t+3  Close_t+4
# Date
# 2013-04-28     134.21     144.54     139.00     116.99     105.21
# 2013-04-29     144.54     139.00     116.99     105.21      97.75

# %%
y_train1.head(2)
# Out:
#             Prediction_t+5
# Date
# 2013-04-28           97.75
# 2013-04-29          112.50

# %%
performance1 = get_performance(X_train_scaled1,y_train_scaled1,X_test_scaled1,y_test_scaled1)
# Out:
# models: 100%|██████████| 6/6 [00:01<00:00,  5.04it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000246 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 1086, number of used features: 5
# [LightGBM] [Info] Start training from score -0.000000

# %%
print_metrics(performance1)
# Out:
# LinearRegression:
# Train scores:{'mse': 0.013878295782546344, 'mae': 0.05560962964219977, 'r2': 0.9861217042174537}
# Test scores:{'mse': 0.08759267171379344, 'mae': 0.1563119606560311, 'r2': 0.9924794853499119}
#
# KNearestNeighbour:
# Train scores:{'mse': 0.012784286719829039, 'mae': 0.05592504671639858, 'r2': 0.987215713280171}
# Test scores:{'mse': 9.541938490524398, 'mae': 1.5249559290610373, 'r2': 0.18075009239697049}
#
# MultilayerPerceptron:
# Train scores:{'mse': 0.016864018299665662, 'mae': 0.06296904997109123, 'r2': 0.9831359817003343}
# Test scores:{'mse': 0.20901483897290055, 'mae': 0.2517292640500773, 'r2': 0.9820544444206745}
#
# SupportVectorRegression:
# Train scores:{'mse': 0.014125505489777422, 'mae': 0.055282598131331566, 'r2': 0.9858744945102226}
# Test scores:{'mse': 0.0867981259770498, 'mae': 0.15626225044237865, 'r2': 0.9925477033039535}
#
# RandomForestRegressor:
# Train scores:{'mse': 0.0024946551067242914, 'mae': 0.023930641040269506, 'r2': 0.9975053448932757}
# Test scores:{'mse': 10.211732717624283, 'mae': 1.5448364517872453, 'r2': 0.12324302931858877}
#
# LightGBMRegressor:
# Train scores:{'mse': 0.009847495797202113, 'mae': 0.04186202187951409, 'r2': 0.9901525042027979}
# Test scores:{'mse': 10.674082529560614, 'mae': 1.6264988950319552, 'r2': 0.08354668867614345}

# %%
plot_pred(performance1,y_train_scaled1,y_test_scaled1)

# %%
compare_models(performance1)

# %% [markdown]
# ## Transformation 2

# %% [markdown]
# > Created a dataframe where window size of 5 indicates seeing the value of 25 previous days, predict the closing price of next 5 days

# %%
df2 = transform_df(df,25, 25,window_size=5)
X_train2, X_test2, y_train2, y_test2 = get_X_y_tts(df2,0.7)
X_train_scaled2, X_test_scaled2 = get_scaled(X_train2,X_test2)
y_train_scaled2, y_test_scaled2 = get_scaled(y_train2,y_test2)

# %%
X_train2.head(2)
# Out:
#             Close_t+0  Close_t+1  Close_t+2  Close_t+3  Close_t+4  Close_t+5  \
# Date
# 2013-04-28     134.21     144.54     139.00     116.99     105.21      97.75
# 2013-04-29     144.54     139.00     116.99     105.21      97.75     112.50
#
#             Close_t+6  Close_t+7  Close_t+8  Close_t+9  ...  Close_t+15  \
# Date                                                    ...
# 2013-04-28     112.50     115.91      112.3     111.50  ...      117.98
# 2013-04-29     115.91     112.30      111.5     113.57  ...      111.50
#
#             Close_t+16  Close_t+17  Close_t+18  Close_t+19  Close_t+20  \
# Date
# 2013-04-28      111.50      114.22      118.76      123.02      123.50
# 2013-04-29      114.22      118.76      123.02      123.50      121.99
#
#             Close_t+21  Close_t+22  Close_t+23  Close_t+24
# Date
# 2013-04-28      121.99      122.00      122.88      123.89
# 2013-04-29      122.00      122.88      123.89      126.70
#
# [2 rows x 25 columns]

# %%
y_train2.head(2)
# Out:
#             Prediction_t+25  Prediction_t+26  Prediction_t+27  \
# Date
# 2013-04-28            126.7           133.20           131.98
# 2013-04-29            133.2           131.98           133.48
#
#             Prediction_t+28  Prediction_t+29
# Date
# 2013-04-28           133.48           129.75
# 2013-04-29           129.75           129.00

# %%
performance2 = get_performance(X_train_scaled2,y_train_scaled2,X_test_scaled2,y_test_scaled2)
# Out:
# models:  83%|████████▎ | 5/6 [00:19<00:05,  5.87s/it]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000351 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6375
# [LightGBM] [Info] Number of data points in the train set: 1069, number of used features: 25
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6630
# [LightGBM] [Info] Number of data points in the train set: 1069, number of used features: 26
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000534 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6885
# [LightGBM] [Info] Number of data points in the train set: 1069, number of used features: 27
# [LightGBM] [Info] Start training from score -0.000000
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000365 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7140
# [LightGBM] [Info] Number of data points in the train set: 1069, number of used features: 28
# [LightGBM] [Info] Start training from score -0.000000
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000378 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7395
# [LightGBM] [Info] Number of data points in the train set: 1069, number of used features: 29
# [LightGBM] [Info] Start training from score -0.000000
# models: 100%|██████████| 6/6 [00:21<00:00,  3.51s/it]

# %%
print_metrics(performance2)
# Out:
# LinearRegression:
# Train scores:{'mse': 0.03266551105295405, 'mae': 0.10008880743068933, 'r2': 0.9673344889470459}
# Test scores:{'mse': 0.3147553001835529, 'mae': 0.3027377231516102, 'r2': 0.973079891375004}
#
# KNearestNeighbour:
# Train scores:{'mse': 0.01124001723845022, 'mae': 0.05204575900392119, 'r2': 0.9887599827615497}
# Test scores:{'mse': 15.870504352161712, 'mae': 2.2596713943171336, 'r2': -0.36818585548572397}
#
# MultilayerPerceptron:
# Train scores:{'mse': 0.024962901447713196, 'mae': 0.09953285824753111, 'r2': 0.9750370985522867}
# Test scores:{'mse': 0.6056816260805356, 'mae': 0.43010640992886734, 'r2': 0.9481888479024002}
#
# SupportVectorRegression:
# Train scores:{'mse': 0.03728168064884614, 'mae': 0.09992298202759395, 'r2': 0.9627183193511538}
# Test scores:{'mse': 0.28457419898886827, 'mae': 0.2792199932507574, 'r2': 0.975659369957173}
#
# RandomForestRegressor:
# Train scores:{'mse': 0.009898859352504313, 'mae': 0.04306584756390007, 'r2': 0.9901011406474955}
# Test scores:{'mse': 12.634715246977308, 'mae': 1.9207237192017033, 'r2': -0.08857096727708076}
#
# LightGBMRegressor:
# Train scores:{'mse': 0.0058482466307728746, 'mae': 0.03688668734777479, 'r2': 0.9941517533692272}
# Test scores:{'mse': 13.264036705725434, 'mae': 2.0100864887558023, 'r2': -0.1443300515948421}

# %%
plot_pred(performance2,y_train_scaled2,y_test_scaled2)

# %%
compare_models(performance2)

# %% [markdown]
# ## LSTM

# %%
def rmse(y_true, y_pred):
    # Using tf.math.sqrt and tf.reduce_mean instead of K.mean and K.square
    return tf.math.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

# %%
model=Sequential()
model.add(LSTM(10,input_shape=(None,1),activation="relu"))
model.add(Dense(1))
model.compile(loss=rmse,optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.0001),metrics=[tf.keras.metrics.MeanAbsoluteError()])

# %%
X_train_s_1 =X_train_scaled1.reshape(X_train1.shape[0],X_train1.shape[1] , 1)
X_test_s_1 = X_test_scaled1.reshape(X_test1.shape[0],X_test1.shape[1] , 1)

# %%
epochs = 100
lstm_model = model.fit(X_train_s_1,y_train_scaled1,validation_data=(X_test_s_1,y_test_scaled1),epochs=epochs,batch_size=32)
# Out:
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.9429 - mean_absolute_error: 0.7130 - val_loss: 3.7681 - val_mean_absolute_error: 3.7268
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9099 - mean_absolute_error: 0.7079 - val_loss: 3.7189 - val_mean_absolute_error: 3.6778
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8819 - mean_absolute_error: 0.6876 - val_loss: 3.6688 - val_mean_absolute_error: 3.6278
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9343 - mean_absolute_error: 0.7138 - val_loss: 3.6184 - val_mean_absolute_error: 3.5775
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8250 - mean_absolute_error: 0.6331 - val_loss: 3.5692 - val_mean_absolute_error: 3.5285
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8251 - mean_absolute_error: 0.6318 - val_loss: 3.5156 - val_mean_absolute_error: 3.4750
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8601 - mean_absolute_error: 0.6426 - val_loss: 3.4609 - val_mean_absolute_error: 3.4205
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8273 - mean_absolute_error: 0.6244 - val_loss: 3.4056 - val_mean_absolute_error: 3.3653
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7725 - mean_absolute_error: 0.5676 - val_loss: 3.3494 - val_mean_absolute_error: 3.3092
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7797 - mean_absolute_error: 0.5775 - val_loss: 3.2889 - val_mean_absolute_error: 3.2489
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7648 - mean_absolute_error: 0.5671 - val_loss: 3.2260 - val_mean_absolute_error: 3.1862
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7429 - mean_absolute_error: 0.5512 - val_loss: 3.1593 - val_mean_absolute_error: 3.1196
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6741 - mean_absolute_error: 0.4977 - val_loss: 3.0916 - val_mean_absolute_error: 3.0520
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6887 - mean_absolute_error: 0.5045 - val_loss: 3.0140 - val_mean_absolute_error: 2.9746
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6448 - mean_absolute_error: 0.4566 - val_loss: 2.9317 - val_mean_absolute_error: 2.8925
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6250 - mean_absolute_error: 0.4303 - val_loss: 2.8390 - val_mean_absolute_error: 2.8001
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6069 - mean_absolute_error: 0.4086 - val_loss: 2.7413 - val_mean_absolute_error: 2.7025
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5397 - mean_absolute_error: 0.3596 - val_loss: 2.6302 - val_mean_absolute_error: 2.5917
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5244 - mean_absolute_error: 0.3308 - val_loss: 2.5054 - val_mean_absolute_error: 2.4672
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4821 - mean_absolute_error: 0.2830 - val_loss: 2.3666 - val_mean_absolute_error: 2.3288
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4847 - mean_absolute_error: 0.2848 - val_loss: 2.2077 - val_mean_absolute_error: 2.1703
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4557 - mean_absolute_error: 0.2591 - val_loss: 2.0359 - val_mean_absolute_error: 1.9987
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3911 - mean_absolute_error: 0.2191 - val_loss: 1.8504 - val_mean_absolute_error: 1.8132
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3490 - mean_absolute_error: 0.1892 - val_loss: 1.6299 - val_mean_absolute_error: 1.5922
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3492 - mean_absolute_error: 0.1887 - val_loss: 1.3931 - val_mean_absolute_error: 1.3532
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3205 - mean_absolute_error: 0.1797 - val_loss: 1.1324 - val_mean_absolute_error: 1.0863
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2893 - mean_absolute_error: 0.1583 - val_loss: 0.8827 - val_mean_absolute_error: 0.8284
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2687 - mean_absolute_error: 0.1584 - val_loss: 0.6674 - val_mean_absolute_error: 0.6118
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2231 - mean_absolute_error: 0.1392 - val_loss: 0.5799 - val_mean_absolute_error: 0.5152
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2026 - mean_absolute_error: 0.1229 - val_loss: 0.5740 - val_mean_absolute_error: 0.5129
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1873 - mean_absolute_error: 0.1187 - val_loss: 0.6202 - val_mean_absolute_error: 0.5551
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1707 - mean_absolute_error: 0.1070 - val_loss: 0.6798 - val_mean_absolute_error: 0.6080
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1809 - mean_absolute_error: 0.1072 - val_loss: 0.7263 - val_mean_absolute_error: 0.6513
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1677 - mean_absolute_error: 0.1032 - val_loss: 0.7674 - val_mean_absolute_error: 0.6891
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1504 - mean_absolute_error: 0.0903 - val_loss: 0.7814 - val_mean_absolute_error: 0.7024
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1473 - mean_absolute_error: 0.0896 - val_loss: 0.7995 - val_mean_absolute_error: 0.7195
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1453 - mean_absolute_error: 0.0816 - val_loss: 0.7688 - val_mean_absolute_error: 0.6892
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1616 - mean_absolute_error: 0.0880 - val_loss: 0.7899 - val_mean_absolute_error: 0.7093
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1274 - mean_absolute_error: 0.0785 - val_loss: 0.7664 - val_mean_absolute_error: 0.6859
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1492 - mean_absolute_error: 0.0836 - val_loss: 0.7705 - val_mean_absolute_error: 0.6896
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1417 - mean_absolute_error: 0.0809 - val_loss: 0.7520 - val_mean_absolute_error: 0.6711
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1603 - mean_absolute_error: 0.0879 - val_loss: 0.7296 - val_mean_absolute_error: 0.6486
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1538 - mean_absolute_error: 0.0857 - val_loss: 0.7159 - val_mean_absolute_error: 0.6348
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1570 - mean_absolute_error: 0.0826 - val_loss: 0.7114 - val_mean_absolute_error: 0.6300
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1604 - mean_absolute_error: 0.0805 - val_loss: 0.7010 - val_mean_absolute_error: 0.6195
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1570 - mean_absolute_error: 0.0843 - val_loss: 0.6688 - val_mean_absolute_error: 0.5872
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1693 - mean_absolute_error: 0.0842 - val_loss: 0.6573 - val_mean_absolute_error: 0.5758
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1396 - mean_absolute_error: 0.0750 - val_loss: 0.6302 - val_mean_absolute_error: 0.5497
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1294 - mean_absolute_error: 0.0731 - val_loss: 0.6399 - val_mean_absolute_error: 0.5583
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1331 - mean_absolute_error: 0.0726 - val_loss: 0.6278 - val_mean_absolute_error: 0.5464
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1381 - mean_absolute_error: 0.0737 - val_loss: 0.6098 - val_mean_absolute_error: 0.5289
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1523 - mean_absolute_error: 0.0748 - val_loss: 0.5989 - val_mean_absolute_error: 0.5183
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1700 - mean_absolute_error: 0.0826 - val_loss: 0.5757 - val_mean_absolute_error: 0.4964
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1533 - mean_absolute_error: 0.0799 - val_loss: 0.5767 - val_mean_absolute_error: 0.4966
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1548 - mean_absolute_error: 0.0801 - val_loss: 0.5599 - val_mean_absolute_error: 0.4806
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1341 - mean_absolute_error: 0.0715 - val_loss: 0.5643 - val_mean_absolute_error: 0.4844
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1506 - mean_absolute_error: 0.0771 - val_loss: 0.5434 - val_mean_absolute_error: 0.4646
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1374 - mean_absolute_error: 0.0745 - val_loss: 0.5408 - val_mean_absolute_error: 0.4618
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1291 - mean_absolute_error: 0.0709 - val_loss: 0.5082 - val_mean_absolute_error: 0.4320
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1381 - mean_absolute_error: 0.0728 - val_loss: 0.4907 - val_mean_absolute_error: 0.4162
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1360 - mean_absolute_error: 0.0739 - val_loss: 0.4866 - val_mean_absolute_error: 0.4117
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1156 - mean_absolute_error: 0.0667 - val_loss: 0.4896 - val_mean_absolute_error: 0.4135
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1616 - mean_absolute_error: 0.0829 - val_loss: 0.4729 - val_mean_absolute_error: 0.3980
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1313 - mean_absolute_error: 0.0710 - val_loss: 0.4616 - val_mean_absolute_error: 0.3871
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1341 - mean_absolute_error: 0.0727 - val_loss: 0.4655 - val_mean_absolute_error: 0.3903
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1263 - mean_absolute_error: 0.0672 - val_loss: 0.4388 - val_mean_absolute_error: 0.3660
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1397 - mean_absolute_error: 0.0696 - val_loss: 0.4371 - val_mean_absolute_error: 0.3639
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1397 - mean_absolute_error: 0.0719 - val_loss: 0.4257 - val_mean_absolute_error: 0.3532
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1464 - mean_absolute_error: 0.0732 - val_loss: 0.4215 - val_mean_absolute_error: 0.3487
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1254 - mean_absolute_error: 0.0692 - val_loss: 0.4216 - val_mean_absolute_error: 0.3486
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1495 - mean_absolute_error: 0.0748 - val_loss: 0.4035 - val_mean_absolute_error: 0.3321
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1251 - mean_absolute_error: 0.0703 - val_loss: 0.4064 - val_mean_absolute_error: 0.3342
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1378 - mean_absolute_error: 0.0710 - val_loss: 0.3881 - val_mean_absolute_error: 0.3172
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1428 - mean_absolute_error: 0.0733 - val_loss: 0.3896 - val_mean_absolute_error: 0.3182
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1209 - mean_absolute_error: 0.0672 - val_loss: 0.3790 - val_mean_absolute_error: 0.3080
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1291 - mean_absolute_error: 0.0707 - val_loss: 0.3681 - val_mean_absolute_error: 0.2972
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1386 - mean_absolute_error: 0.0737 - val_loss: 0.3617 - val_mean_absolute_error: 0.2906
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1438 - mean_absolute_error: 0.0751 - val_loss: 0.3622 - val_mean_absolute_error: 0.2910
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1302 - mean_absolute_error: 0.0699 - val_loss: 0.3571 - val_mean_absolute_error: 0.2856
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1307 - mean_absolute_error: 0.0678 - val_loss: 0.3504 - val_mean_absolute_error: 0.2787
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1163 - mean_absolute_error: 0.0650 - val_loss: 0.3422 - val_mean_absolute_error: 0.2704
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1314 - mean_absolute_error: 0.0717 - val_loss: 0.3437 - val_mean_absolute_error: 0.2716
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1264 - mean_absolute_error: 0.0701 - val_loss: 0.3402 - val_mean_absolute_error: 0.2681
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1157 - mean_absolute_error: 0.0639 - val_loss: 0.3337 - val_mean_absolute_error: 0.2615
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1340 - mean_absolute_error: 0.0716 - val_loss: 0.3330 - val_mean_absolute_error: 0.2609
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1405 - mean_absolute_error: 0.0727 - val_loss: 0.3221 - val_mean_absolute_error: 0.2503
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1240 - mean_absolute_error: 0.0666 - val_loss: 0.3232 - val_mean_absolute_error: 0.2510
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1315 - mean_absolute_error: 0.0702 - val_loss: 0.3219 - val_mean_absolute_error: 0.2497
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1356 - mean_absolute_error: 0.0699 - val_loss: 0.3190 - val_mean_absolute_error: 0.2469
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1202 - mean_absolute_error: 0.0636 - val_loss: 0.3161 - val_mean_absolute_error: 0.2442
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1422 - mean_absolute_error: 0.0707 - val_loss: 0.3159 - val_mean_absolute_error: 0.2439
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1271 - mean_absolute_error: 0.0684 - val_loss: 0.3060 - val_mean_absolute_error: 0.2341
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1407 - mean_absolute_error: 0.0731 - val_loss: 0.3020 - val_mean_absolute_error: 0.2299
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1228 - mean_absolute_error: 0.0655 - val_loss: 0.3003 - val_mean_absolute_error: 0.2282
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1420 - mean_absolute_error: 0.0748 - val_loss: 0.2993 - val_mean_absolute_error: 0.2269
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1373 - mean_absolute_error: 0.0700 - val_loss: 0.2980 - val_mean_absolute_error: 0.2255
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1318 - mean_absolute_error: 0.0691 - val_loss: 0.2932 - val_mean_absolute_error: 0.2210
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1228 - mean_absolute_error: 0.0643 - val_loss: 0.2915 - val_mean_absolute_error: 0.2193
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1378 - mean_absolute_error: 0.0723 - val_loss: 0.2893 - val_mean_absolute_error: 0.2180
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1230 - mean_absolute_error: 0.0634 - val_loss: 0.2908 - val_mean_absolute_error: 0.2183

# %%
fig, axs = plt.subplots(1, 2,figsize=(18,5))

axs[0].plot(range(epochs), lstm_model.history['loss'], label='Train')
axs[0].plot(range(epochs), lstm_model.history['val_loss'], label='Validation')
axs[0].set_title('Root Mean Squared Error')
axs[0].set_xlabel("Epoch Number")
axs[0].set_ylabel("rmse")
axs[0].legend()

axs[1].plot(range(epochs), lstm_model.history['mean_absolute_error'], label='Training')
axs[1].plot(range(epochs), lstm_model.history['val_mean_absolute_error'], label='Validation')
axs[1].set_title('Mean Absolute Error')
axs[1].set_xlabel("Epoch Number")
axs[1].set_ylabel("mae")
axs[1].legend()

plt.suptitle("Epoch vs Error")
plt.show()

# %%
yptr1 = model.predict(X_train_s_1)
ypts1 = model.predict(X_test_s_1)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
print("Metrics-")
print(f"Train scores: mse: {mse(y_train_scaled1,yptr1)}, mae: {mae(y_train_scaled1,yptr1)}, r2: {r2_s(y_train_scaled1,yptr1)}")
print(f"Test scores: mse: {mse(y_test_scaled1,ypts1)}, mae: {mae(y_test_scaled1,ypts1)}, r2: {r2_s(y_test_scaled1,ypts1)}")
# Out:
# Metrics-
# Train scores: mse: 0.02009524080345834, mae: 0.06815160698743919, r2: 0.9799047591965416
# Test scores: mse: 0.197653825757646, mae: 0.21829881833409054, r2: 0.9830298760938211

# %%
train_len = len(y_train_scaled1)
test_len = len(y_test_scaled1)

fig, axs = plt.subplots(1, 2,figsize=(24,5))
axs[0].plot(np.arange(train_len),y_train_scaled1,label='Actual')
axs[0].plot(np.arange(train_len),yptr1,label='Predicted',alpha=0.8)
axs[0].set_title(f"y_train")
axs[0].legend()

axs[1].plot(np.arange(test_len),y_test_scaled1,label='Actual')
axs[1].plot(np.arange(test_len),ypts1,label='Predicted',alpha=0.8)
axs[1].set_title(f"y_test")
axs[1].legend()

plt.suptitle("LSTM")
plt.show()
